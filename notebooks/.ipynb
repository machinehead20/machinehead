# %%
import pandas as pd
import numpy as np
import sqlite3
from sqlalchemy import create_engine

# %%
db_path = '../data/raw/machinehead20.db'

# %%
db_engine = create_engine(f'sqlite:///{db_path}')

# %%
pd.read_sql_query("SELECT name FROM sqlite_master WHERE type='table'", db_engine)
# Out:
#             name
# 0      rank_info
# 1  personal_info
# 2  business_info

# %%
# You call this function when you want to see one of the tables as a Panda's dataframe
def table_to_df(table_name):
    df = pd.read_sql_query(f'SELECT * FROM {table_name}', db_engine)
    return df

def describe_df(table_name):
    description = table_to_df(table_name).describe()
    return description

# %%
describe_df('rank_info')
# Out:
#                 id     position   Unnamed: 0
# count  2260.000000  2208.000000  2260.000000
# mean   5558.170354  1104.500000  1129.500000
# std    2612.271048   637.539018   652.550126
# min    1008.000000     1.000000     0.000000
# 25%    3280.750000   552.750000   564.750000
# 50%    5670.500000  1104.500000  1129.500000
# 75%    7840.250000  1656.250000  1694.250000
# max    9993.000000  2208.000000  2259.000000

# %%
df_table_to_df('personal_info')
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# <ipython-input-48-acdf6c055321> in <module>
# ----> 1 df_table_to_df('personal_info')
#
# NameError: name 'df_table_to_df' is not defined

# %%
table_to_df('business_info')
# Out:
#         id  Unnamed: 0                                           Source  \
# 0     8098          52                           Technology  ==> Amazon
# 1     3112          53                        Technology  ==> Microsoft
# 2     7509          54  Finance and Investments  ==> Berkshire Hathaway
# 3     3270          55                       Fashion & Retail  ==> LVMH
# 4     6859          56                         Technology  ==> Facebook
# ...    ...         ...                                              ...
# 2203  4528        2255     Fashion & Retail  ==> fashion, entertainment
# 2204  8782        2256          Manufacturing  ==> electrical equipment
# 2205  6135        2257          Manufacturing  ==> electrical equipment
# 2206  3197        2258        Manufacturing  ==> printed circuit boards
# 2207  7080        2259                     Diversified  ==> diversified
#
#            worth          worthChange realTimeWorth  realTimePosition
# ...
